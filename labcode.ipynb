# %%
import csv
# file = open('/Users/jonah/Downloads/bootstrap_result_finalSheet12.csv')
# type(file)
# csvreader = csv.reader(file)


with open('/Users/jonah/Downloads/bootstrap_result_finalSheet12.csv') as file:
    content = file.readlines()
# header = content[:1]
# rows = content[1:]

temp = content[2:3]
print(temp[0])
srting = str(temp[0])
print(string)
# f =  open('/Users/jonah/Downloads/bootstrap_result_finalSheet12.csv')

# for line1 in first_line:
#     name = line1.strip()
#     print(name)
# x = first_line.split()
# for i in x:
#     for y in x[x.index(i)+1:]:
#         print(y)
        
        #print(i+"\t"+y)
    #print("\n")
#print()
# Out:
# Y0_MDD,Y1_MDD,1,1,-->,100,100,0,0,0,0,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->,-->
#
# Y1_MUD Y1_ND

# %%
import os
os.getcwd()
# Out:
# '/Users/jonah'

# %%
# Checking for both have
# Checking for the two different dataset, how much difference will be there.6


def starts_with_number(line):
    """Returns True if the given line starts with a number, False otherwise."""
    if line.strip() == "":
        return False  # skip empty lines
    first_char = line.strip()[0]  # get the first non-space character
    return first_char.isdigit()  # check if it's a digit

import filecmp

# reading files
f1 = open('/Users/jonah/Downloads/Luposendgraphcopy.txt', "r") 
f2 = open('/Users/jonah/Desktop/reuslt/graspfci_1686168513146_out.txt', "r") 

f1_data = f1.readlines() 
f2_data = f2.readlines()
i = 0
count = 1
find = False
for line1 in f1_data:
    if starts_with_number(line1):
        i += 1
        find = False
        for line2 in f2_data:
            space_count = 0
            index = -1
            line2= line2.replace('"', "").replace('"','')
            if starts_with_number(line2):
                #first_char = line2.strip()[3:]
                if line2.strip()[5:] in line1:
                #if line1.find(line2.strip()[3:])==True:
                    print(line1)
                    while space_count < 2:
                        index = line1.find(' ', index + 1)
                        if index == -1:
                            break
                        space_count += 1
                    print(line1.strip()[index+1:index+4])
                    #print("Yes--------------------------------------")
                    count = count + 1
                    find = True
                    #print("Line ", i, ": IDENTICAL")
                    break
        if find == False:
            print("None")
        #    print(line1)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# 9. Y0_AGOR --> Y1_AGOR
#
# -->
# 10. Y0_ARREST --> Y1_ARREST
#
# -->
# None
# None
# None
# 14. Y0_CD --> Y0_IMP_Behavior
#
# -->
# 15. Y0_CD --> Y0_IMP_Parents
#
# -->
# 16. Y0_CD --> Y1_ND
#
# -->
# None
# 18. Y0_DB_Gen-Del --> Y1_DB_Alone_Group
#
# -->
# None
# None
# 21. Y0_IMP_Activities --> Y0_PD_Depres
#
# -->
# 22. Y0_IMP_Behavior --> Y0_IMP_Home
#
# -->
# None
# 24. Y0_IMP_Parents --> Y1_IMP_Home
#
# -->
# None
# None
# None
# 28. Y0_PD_Depres --> Y1_PD_Depres
#
# -->
# None
# 30. Y0_PD_Hostility --> Y0_PD_Eccentr
#
# -->
# 31. Y0_PD_Impul --> Y1_PD_Impul
#
# -->
# None
# 33. Y0_PD_Suspic --> Y1_PD_Susp-Eccentr
#
# -->
# None
# 35. Y0_PTSD --> Y0_AGOR
#
# -->
# None
# 37. Y0_SAD --> Y0_PD_Sep-Insec
#
# -->
# None
# 39. Y1_AUD --> Y1_DB_Group
#
# -->
# 40. Y1_Age --> Y1_CD
#
# -->
# 41. Y1_CD --> Y1_DB_Alone
#
# -->
# 42. Y1_DB_Alone_Group --> Y1_DB_Group
#
# -->
# None
# 44. Y1_IMP_Depr-Anx --> Y1_IMP_Activities
#
# ...

# %%
# Checking for f1 have and f2 don't have 
def starts_with_number(line):
    """Returns True if the given line starts with a number, False otherwise."""
    if line.strip() == "":
        return False  # skip empty lines
    first_char = line.strip()[0]  # get the first non-space character
    return first_char.isdigit()  # check if it's a digit

import filecmp

# reading files
f1 = open('/Users/jonah/Downloads/Luposendgraphcopy.txt', "r") 
f2 = open('/Users/jonah/Desktop/reuslt/graspfci_1686168513146_out.txt', "r") 


f1_data = f1.readlines() 
f2_data = f2.readlines()
i = 0
count = 1
find = False
for line1 in f1_data:
    #if starts_with_number(line1):
        i += 1
        find = False
        for line2 in f2_data:
        #    if starts_with_number(line2):
                #first_char = line2.strip()[3:]
                if line2.strip()[5:] in line1:
                #if line1.find(line2.strip()[3:])==True:
                    print(line1)
                    #print(line1)
                    #print("Yes--------------------------------------")
                    count = count + 1
                    find = True
                    #print("Line ", i, ": IDENTICAL")
                    break
        if find == False:
            print(line1)
# Out:
# Graph Edges:
#
# 1. Y0_GAD --> Y0_PD
#
# 2. Y0_IMP_Help --> Y0_IMP_Behavior
#
# 3. Y0_IMP_Help --> Y1_IMP_Help
#
# 4. Y0_M --> Y0_IMP_Activities
#
# 5. Y0_M --> Y0_IMP_Parents
#
# 6. Y0_M --> Y1_M
#
# 7. Y0_PTSD --> Y1_PTSD
#
# 8. Y0_AGOR --> Y0_IMP_Depr-Anx
#
# 9. Y0_AGOR --> Y1_AGOR
#
# 10. Y0_ARREST --> Y1_ARREST
#
# 11. Y0_AU_4Drinks --> Y0_AU_Freq
#
# 12. Y0_AU_Drinks --> Y0_PD_Depres
#
# 13. Y0_CD --> Y0_ARREST
#
# 14. Y0_CD --> Y0_IMP_Behavior
#
# 15. Y0_CD --> Y0_IMP_Parents
#
# 16. Y0_CD --> Y1_ND
#
# 17. Y0_DB_Gen-Del --> Y1_AUD
#
# 18. Y0_DB_Gen-Del --> Y1_DB_Alone_Group
#
# 19. Y0_GAD --> Y0_AGOR
#
# 20. Y0_IMP_Activities --> Y0_IMP_Depr-Anx
#
# 21. Y0_IMP_Activities --> Y0_PD_Depres
#
# 22. Y0_IMP_Behavior --> Y0_IMP_Home
#
# 23. Y0_IMP_Help --> Y0_IMP_Activities
#
# 24. Y0_IMP_Parents --> Y1_IMP_Home
#
# 25. Y0_M --> Y0_GAD
#
# 26. Y0_M --> Y0_PTSD
#
# 27. Y0_PD_Cog-Perc-Dys --> Y1_PD_Perc-Dys_Sep-Ins
#
# 28. Y0_PD_Depres --> Y1_PD_Depres
#
# ...

# %%
def starts_with_number(line):
    """Returns True if the given line starts with a number, False otherwise."""
    if line.strip() == "":
        return False  # skip empty lines
    first_char = line.strip()[0]  # get the first non-space character
    return first_char.isdigit()  # check if it's a digit

import filecmp


# reading files
f1 = open('/Users/jonah/Downloads/result/graspfci_1688051225255_out.txt', "r") 
f2 = open('/Users/jonah/Downloads/result/graspfci_1688051226768_out.txt', "r") 
f3 = open('/Users/jonah/Downloads/result/graspfci_1688051228086_out.txt', "r") 
f4 = open('/Users/jonah/Downloads/result/graspfci_1688051229482_out.txt', "r") 
f5 = open('/Users/jonah/Downloads/result/graspfci_1688051230625_out.txt', "r") 
f6 = open('/Users/jonah/Downloads/result/graspfci_1688051232159_out.txt', "r") 
f7 = open('/Users/jonah/Downloads/result/graspfci_1688051233603_out.txt', "r") 
f8 = open('/Users/jonah/Downloads/result/graspfci_1688051235234_out.txt', "r") 
f9 = open('/Users/jonah/Downloads/result/graspfci_1688051236425_out.txt', "r") 
my_list = [f1,f2,f3,f4,f5,f6,f7,f8,f9]

#f1 = open('/Users/jonah/Downloads/originalresult.txt', "r") 
#f2 = open('/Users/jonah/Downloads/dataresult/graspfci_1684081663131_out.txt', "r") 

#f1_data = f1.readlines() 

#for i in range(0,8):
#    fdata = my_list[i].readlines()
f1_data = f1.readlines()
for line1 in f1_data:
    if starts_with_number(line1):
        print(line1)
#M0_CJSI       F0_CJSI
        with open('/Users/jonah/Downloads/Y0_Y1_Model_3.csv1(2).txt') as f:
            first_line = f.readline()
            x = first_line.split()
            for item1 in x:
                loc = -1
                space_count = 0
                if item1 in line1:
                    for item2 in x[x.index(item1)+1:]:
                        if item2 in line1:
                            while space_count < 2:
                                loc = line1.find(' ', loc + 1)
                                space_count += 1
                            print(line1.strip()[loc+1:loc+4])           
            else:
                print("None")
                

# f1_data = f1.readlines() 
# f2_data = f2.readlines()
# i = 0
# count = 1
# find = False
# for line1 in f1_data:
#     if starts_with_number(line1):
#         i += 1
#         find = False
#         for line2 in f2_data:
#             space_count = 0
#             index = -1
#             line2= line2.replace('"', "").replace('"','')
#             if starts_with_number(line2):
#                 #first_char = line2.strip()[3:]
#                 if line2.strip()[5:] in line1:
#                 #if line1.find(line2.strip()[3:])==True:
#                     print(line1)
#                     while space_count < 2:
#                         index = line1.find(' ', index + 1)
#                         if index == -1:
#                             break
#                         space_count += 1
#                     print(line1.strip()[index+1:index+4])
#                     #print("Yes--------------------------------------")
#                     count = count + 1
#                     find = True
#                     #print("Line ", i, ": IDENTICAL")
#                     break
#         if find == False:
#             print("None")
        #    print(line1)
# Out:
# 1. "M0_CJSI" --> "F0_CJSI"
#
# -->
# None
# 2. "Y0_AGOR" --> "Y0_IMP_Depr.Anx"
#
# None
# 3. "Y0_AGOR" --> "Y0_PTSD"
#
# -->
# None
# 4. "Y0_AGOR" --> "Y1_IMP_Depr.Anx"
#
# None
# 5. "Y0_ARREST" --> "Y0_AU_Freq"
#
# -->
# None
# 6. "Y0_AU_4Drinks" --> "Y1_DB_Group"
#
# -->
# None
# 7. "Y0_AU_Drunk" --> "Y0_AU_Drinks"
#
# -->
# None
# 8. "Y0_AU_Freq" --> "Y0_AU_4Drinks"
#
# -->
# None
# 9. "Y0_AU_Freq" --> "Y0_AU_Drinks"
#
# -->
# None
# 10. "Y0_AU_Freq" --> "Y0_AU_Drunk"
#
# -->
# None
# 11. "Y0_Age" --> "Y0_PD_Cog.Perc.Dys"
#
# -->
# None
# 12. "Y0_Age" --> "Y1_Age"
#
# -->
# None
# 13. "Y0_CD" --> "Y1_ARREST"
#
# -->
# None
# 14. "Y0_CD" --> "Y1_CD"
#
# -->
# None
# 15. "Y0_CD" --> "Y1_ND"
#
# -->
# None
# 16. "Y0_DB_Gen.Del" --> "Y0_ARREST"
#
# None
# 17. "Y0_DB_Gen.Del" --> "Y0_DB_SnJ"
#
# None
# 18. "Y0_DB_Gen.Del" --> "Y1_DB_Alone_Group"
#
# -->
# None
# 19. "Y0_DB_SnJ" --> "Y0_AU_Freq"
#
# -->
# None
# 20. "Y0_DB_SnJ" --> "Y0_Age"
#
# -->
# None
# 21. "Y0_DB_SnJ" --> "Y0_CD"
# ...

# %%
def starts_with_number(line):
    """Returns True if the given line starts with a number, False otherwise."""
    if line.strip() == "":
        return False  # skip empty lines
    first_char = line.strip()[0]  # get the first non-space character
    return first_char.isdigit()  # check if it's a digit

import filecmp
# # reading files
# f1 = open('/Users/jonah/Downloads/Y0_Y1_Model_3.csv1(2).txt', "r") 
# f1_data = f1.readlines()
# for line1 in f1_data:
#     print(line1)
# for i in range(0,100):
#     name = "/Users/jonah/Downloads/dataresult/boot"+i
f =  open('/Users/jonah/Downloads/Jonah_Y0_Y1_Model_3.csv1_final_copy.txt')
f2 = open('/Users/jonah/Downloads/lab_data/graspfci_1702925838821_out.txt', "r") 
first_line = f.readline()
f2_data = f2.readlines() 
#print(first_line)
# with open("output.txt", "w") as file:    
#     x = first_line.split()
#     for item1 in x:
#         for item2 in x[x.index(item1)+1:]:
#             file.write(item1+"       "+item2+"\n")
#             print(item1+"       "+item2)
i = 0
j = 0 
x = first_line.split()
for item1 in x:
    for item2 in x[x.index(item1)+1:]: 
        find = False;
        string = item1 +" "+ item2;
        #print(string)
        i = i +1
        for line2 in f2_data:
            space_count = 0
            index = -1
            line2= line2.replace('"', "").replace('"','')
            if starts_with_number(line2):
                if item1 in line2:
                    if item2 in line2:
#                         print(item1+" "+ item2)
#                         print(line2)
#                         print(line2)
                        while space_count < 2:
                            index = line2.find(' ', index + 1)
                            if index == -1:
                                break
                            space_count += 1
                        print(line2.strip()[index+1:index+4]) 
                        find = True

                        break
        if find == False:
            print("None")
# Out:
# <->
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# o->
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...

# %%
for i in range(0,100):
    name = "/Users/jonah/Downloads/dataresult/boot"+str(i)
print(name)
# Out:
# /Users/jonah/Downloads/dataresult/boot99

# %%
def starts_with_number(line):
    """Returns True if the given line starts with a number, False otherwise."""
    if line.strip() == "":
        return False  # skip empty lines
    first_char = line.strip()[0]  # get the first non-space character
    return first_char.isdigit()  # check if it's a digit
import filecmp
# # reading files
# f1 = open('/Users/jonah/Downloads/Y0_Y1_Model_3.csv1(2).txt', "r") 
# f1_data = f1.readlines()
# for line1 in f1_data:
#     print(line1)
f5 = open("demofile2.txt", "w")

for i in range(1,100):
    filename = ('/Users/jonah/Downloads/result/'+str(i)+'_out.txt')
    f =  open('/Users/jonah/Downloads/Jonah_Y0_Y1_Model_3.csv1_final_copy.txt')
    f2 = open(filename, "r") 
    first_line = f.readline()
    f2_data = f2.readlines() 
    #print(first_line)
    #with open("result.txt", "w") as file:    
    #x = first_line.split()
    #     for item1 in x:
    #         for item2 in x[x.index(item1)+1:]:
    #             file.write(item1+"       "+item2+"\n")
    #             print(item1+"       "+item2)
    i = 0
    j = 0 
    x = first_line.split()
    for item1 in x:
        for item2 in x[x.index(item1)+1:]: 
            find = False;
            string = item1 +" "+ item2;
            #         print(string)
            i = i +1
            for line2 in f2_data:
                space_count = 0
                index = -1
                line2= line2.replace('"', "").replace('"','')
                if starts_with_number(line2):
                    if item1 in line2:
                        if item2 in line2:
    #                         print(item1+" "+ item2)
    #                         print(line2)
    #                         print(line2)
                            while space_count < 2:
                                index = line2.find(' ', index + 1)
                                if index == -1:
                                    break
                                space_count += 1
                            name = line2.strip()[index+1:index+4]
                            f5.write(name) 
                            find = True
                            break
            if find == False:
                f5.write("None")
            f5.write("\t")
    f5.write("\n")
f5.close()

# %%
def starts_with_number(line):
    """Returns True if the given line starts with a number, False otherwise."""
    if line.strip() == "":
        return False  # skip empty lines
    first_char = line.strip()[0]  # get the first non-space character
    return first_char.isdigit()  # check if it's a digit
import filecmp
# # reading files
# f1 = open('/Users/jonah/Downloads/Y0_Y1_Model_3.csv1(2).txt', "r") 
# f1_data = f1.readlines()
# for line1 in f1_data:
#     print(line1)
f5 = open("demofile2.txt", "w")

f =  open('/Users/jonah/Downloads/Jonah_Y0_Y1_Model_3.csv1_final_copy.txt')

first_line = f.readline()

#print(first_line)
#with open("result.txt", "w") as file:    
#x = first_line.split()
#     for item1 in x:
#         for item2 in x[x.index(item1)+1:]:
#             file.write(item1+"       "+item2+"\n")
#             print(item1+"       "+item2)
i = 0
j = 0 
x = first_line.split()
for item1 in x:
    for item2 in x[x.index(item1)+1:]: 
        for k in range(1,101):
            filename = ('/Users/jonah/Downloads/dataresult/'+str(k)+'_out.txt')
            f2 = open(filename, "r") 
            f2_data = f2.readlines() 
            find = False;
            string = item1 +" "+ item2;
            #         print(string)
            i = i +1
            for line2 in f2_data:
                space_count = 0
                index = -1
                line2= line2.replace('"', "").replace('"','')
                if starts_with_number(line2):
                    if item1 in line2:
                        if item2 in line2:
    #                         print(item1+" "+ item2)
    #                         print(line2)
    #                         print(line2)
                            while space_count < 2:
                                index = line2.find(' ', index + 1)
                                if index == -1:
                                    break
                                space_count += 1
                            name = line2.strip()[index+1:index+4]
                            f5.write(name) 
                            find = True
                            break
            if find == False:
                f5.write("None")
            f5.write("\t")
        f5.write("\n")
f5.close()

# %%
# Out:
# {'M0_CJSI': [], 'F0_CJSI': [], 'Y0_Male': ['Y0_PD_Eccentr'], 'Y0_Age': ['Y0_PD_Cog_Perc_Dys', 'Y0_SAD', 'Y1_PD_Perc_Dys_Sep_Ins', 'Y0_IMP_Behavior'], 'Y0_DB_Gen_Del': ['Y1_DB_Alone_Group', 'Y0_CD'], 'Y0_DB_SnJ': ['Y0_DB_Gen_Del', 'Y0_IMP_Home', 'Y0_PD_Suspic', 'Y1_DB_Group', 'Y1_GAD'], 'Y0_ARREST': ['Y0_AU_Freq', 'Y0_CD', 'Y0_DB_Gen_Del', 'Y1_ARREST', 'Y1_IMP_Depr_Anx'], 'Y0_PD_Depres': ['Y0_MDD'], 'Y0_PD_Suspic': ['Y0_IMP_Depr_Anx', 'Y0_PD_Cog_Perc_Dys', 'Y0_PD_Eccentr', 'Y0_PD_Hostility', 'Y0_PD_Impul', 'Y0_PD_Withdr', 'Y1_PD_Susp_Eccentr', 'Y1_PD_Withdr'], 'Y0_PD_Cog_Perc_Dys': [], 'Y0_PD_Impul': ['Y1_PD_Impul', 'Y0_AGOR'], 'Y0_PD_Eccentr': ['Y0_PD_Depres', 'Y0_PD_Odd_Bel_Exp', 'Y0_PD_Cog_Perc_Dys'], 'Y0_PD_Odd_Bel_Exp': [], 'Y0_PD_Hostility': [], 'Y0_PD_Sep_Insec': [], 'Y0_PD_Withdr': ['Y1_PTSD'], 'Y0_AU_Freq': ['Y0_AU_Drinks', 'Y0_IMP_Depr_Anx'], 'Y0_AU_Drinks': ['Y0_PD_Depres', 'Y0_AU_4Drinks'], 'Y0_AU_4Drinks': ['Y0_AU_Drunk'], 'Y0_AU_Drunk': [], 'Y0_IMP_Home': ['Y0_IMP_Behavi
# ...
